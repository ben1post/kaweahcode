# %%
import numpy as np
import xsimlab as xs
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %% [markdown]
# # TODO
# - implement a full component index for model output! (maybe later though, make sure to have all dimensions indexed, is all)
# - is odeint usage possible? by passing run_step as function (any_object?), instead passing array values?
# - implement external initialisations for Components, like Allometric Phytoplankton

# %%
# This definitely also makes sense, but just as construction help for future components (and building block of the current ones)
@xs.process
class Time:
    days = xs.variable(dims='time', description='time in days')
    # for indexing xarray IO objects
    # NOTE: this is what allows storing the output along time properly even when using odeint!
    time = xs.index(dims='time', description='time in days')
    
    def initialize(self):
        self.time = self.days

        
        
        
        
        
@xs.process
class Component:
    """Base class encoding behaviour for a component of a ecosystem.
        subclass needs to have implemented:
        self.num, self.component_label, self.init, 
        
    """
    num = xs.variable(dims=(),intent='in')
    
    def initialize(self):
        self.state = self.init
        if self.num:
            self.label = np.array([f"{self.component_label}-{i+1}" for i in range(self.num)])
        else:
            self.label = self.component_label
        print(self.label)
        print(self.init)
        
    def run_step(self):
        print('step', self.label)
        # Note to self: sum yields1D array, due to generator unpacking within sum
        self._delta = np.array(sum((v for v in self.fluxes))) #maybe can remove forcing to numpy array here later
        print(self._delta)

    def finalize_step(self):
        #if self._delta == None:
        #    raise('No fluxes defined!')
        print('finalize', self.state)
        self.state += self._delta
        
@xs.process
class Nutrient(Component):
    """"""
    component_label = xs.variable(default='N', groups='component-label', static=True)
    label = xs.index(dims='N')
    
    fluxes = xs.group('n_flux')
    state = xs.variable(dims='N', intent='out', groups = 'state-variables', description='component array', attrs={'units': 'µM N'})

    # PARAMETERS / INPUTS
    num = xs.variable(default=1, static=True, description='number of nutrients (1 by default)')
    init = xs.variable(dims='N', intent='in')
            
@xs.process
class Phytoplankton(Component):
    """"""
    component_label = xs.variable(default='P', groups='component-label', static=True)
    label = xs.index(dims='P')
    
    fluxes = xs.group('p_flux')
    state = xs.variable(dims='P', intent='out', groups = 'state-variables', description='component array', attrs={'units': 'µM N'})
    
    # PARAMETERS / INPUTS
    init = xs.variable(dims='P',intent='in')
    halfsat = xs.variable(intent='in', dims='P', groups='parameters')


@xs.process
class ChemostatSetup:
    P_num = xs.variable(intent='in', dims=(), static=True, description='number of Phytoplankton')
    P_initVal = xs.variable(intent='in', dims=[(), 'P'], static=True, description='initial Phytoplankton biomass')
    halfsat = xs.variable(intent='in', dims=[(), 'P'], static=True, description='half-saturation constant of nutrient uptake for P')

    P_num_out = xs.foreign(Phytoplankton, 'num', intent='out')    
    P_init = xs.foreign(Phytoplankton, 'init', intent='out')
    halfsat_out = xs.foreign(Phytoplankton, 'halfsat', intent='out')
    
    N_initVal = xs.variable(intent='in', static=True, description='initial Nutrient concentration')
    N_init = xs.foreign(Nutrient, 'init', intent='out')

    
    def initialize(self):
        print('init')
        self.P_num_out = self.P_num
        self.halfsat_out = np.array([self.halfsat for i in range(self.P_num)])
        self.P_init = np.array([self.P_initVal for i in range(self.P_num)])
        self.N_init = np.array([self.N_initVal for i in range(1)])

        
        
        
        
        
        
@xs.process
class PhytoplanktonGrowth:
    """"""
    growth = xs.variable(
        dims='P',
        intent='out',
        groups=['p_flux'],
        description='phytoplankton growth, under light & nutrient limitation'
    )
    
@xs.process
class NutrientUptake(PhytoplanktonGrowth):
    """"""
    N = xs.foreign(Nutrient, 'state')
    P = xs.foreign(Phytoplankton, 'state')
    P_halfsat = xs.foreign(Phytoplankton, 'halfsat')
    
    def run_step(self):
        self.growth = self.N / (self.P_halfsat + self.N) * self.P
    
    
@xs.process
class Forcing:
    """Sum up all forcing processes and their effects, respectively.
    """
    pass
    

class NutrientSource(Forcing):
    """Chemostat constant nutrient inflow from one direction"""
    forcing_flux = xs.variable(
        dims=[(), 'N'],
        intent='out',
        groups='n_flux',
        description='constant nutrient influx'
    )

    #N = xs.foreign(Nutrient, 'state')
    
    #@xs.runtime(args='step_delta')
    def run_step(self):
        self.forcing_flux = 0.1

# %%
mod = xs.Model(
    {
        'ModelSetup':ChemostatSetup,
        'N':Nutrient, 
        'P':Phytoplankton#, 
        #'N_Uptake':NutrientUptake, 
        #'N_source':NutrientSource
    }
)

# %%
mod
# Out:
# <xsimlab.Model (3 processes, 7 inputs)>
# ModelSetup
#     halfsat             [in] () or ('P',) half-saturation constant ...
#     P_num               [in] number of Phytoplankton
#     P_initVal           [in] () or ('P',) initial Phytoplankton bio...
#     N_initVal           [in] initial Nutrient concentration
# N
#     component_label     [in]
#     num                 [in] number of nutrients (1 by default)
# P
#     component_label     [in]

# %%
in_ds = xs.create_setup(
     model=mod,
     clocks={
         'time': np.linspace(0., 1., 3)#,
         #'otime': [0, 0.1, 0.5, 1]
     },
     master_clock='time',
     input_vars={
         'ModelSetup':{'P_num':3,'P_initVal':1,'halfsat':0.5, 'N_initVal':1}
     },
     output_vars={
        'P__state': 'time',
        'N__state': 'time'
     }
 )

# %%
with mod:
    in_ds.xsimlab.run()
# Out:
# init
# ['N-1']
# [1]
# ['P-1' 'P-2' 'P-3']
# [1 1 1]
# step ['N-1']
# 0
# step ['P-1' 'P-2' 'P-3']
# 0
# finalize [1]
# finalize [1 1 1]
# step ['N-1']
# 0
# step ['P-1' 'P-2' 'P-3']
# 0
# finalize [1]
# finalize [1 1 1]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-168-fa8a2d0e11a5> in <module>
#       1 with mod:
# ----> 2     in_ds.xsimlab.run()
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.8/site-packages/xsimlab/xr_accessor.py in run(self, model, batch_dim, check_dims, validate, store, encoding, hooks, parallel, scheduler, safe_mode)
#     814         )
#     815
# --> 816         driver.run_model()
#     817
#     818         return driver.get_results()
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.8/site-packages/xsimlab/drivers.py in run_model(self)
#     453
#     454         if self.batch_dim is None:
# --> 455             _run(
#     456                 ds_in,
#     457                 self.model,
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.8/site-packages/xsimlab/drivers.py in _run(dataset, model, store, hooks, validate, batch, batch_size, parallel, scheduler)
#     354     model.execute("finalize", rt_context, **execute_kwargs)
#     355
# --> 356     store.write_index_vars(model=model)
#     357
#     358
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.8/site-packages/xsimlab/stores.py in write_index_vars(self, model)
#     326
#     327             self._create_zarr_dataset(model, var_key, name=vname)
# --> 328             self.zgroup[vname][:] = model.cache[var_key]["value"]
#     329
#     330     def consolidate(self):
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.8/site-packages/zarr/core.py in __setitem__(self, selection, value)
#    1113
#    1114         fields, selection = pop_fields(selection)
# -> 1115         self.set_basic_selection(selection, value, fields=fields)
#    1116
#    1117     def set_basic_selection(self, selection, value, fields=None):
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.8/site-packages/zarr/core.py in set_basic_selection(self, selection, value, fields)
#    1208             return self._set_basic_selection_zd(selection, value, fields=fields)
#    1209         else:
# -> 1210             return self._set_basic_selection_nd(selection, value, fields=fields)
#    1211
#    1212     def set_orthogonal_selection(self, selection, value, fields=None):
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.8/site-packages/zarr/core.py in _set_basic_selection_nd(self, selection, value, fields)
#    1499         indexer = BasicIndexer(selection, self)
#    1500
# -> 1501         self._set_selection(indexer, value, fields=fields)
#    1502
#    1503     def _set_selection(self, indexer, value, fields=None):
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.8/site-packages/zarr/core.py in _set_selection(self, indexer, value, fields)
#    1527             if not hasattr(value, 'shape'):
#    1528                 value = np.asanyarray(value)
# -> 1529             check_array_shape('value', value, sel_shape)
#    1530
#    1531         # iterate over chunks in range
#
# ~/opt/anaconda3/envs/xsimlab2/lib/python3.8/site-packages/zarr/util.py in check_array_shape(param, array, shape)
#     502                         .format(param, type(array)))
#     503     if array.shape != shape:
# --> 504         raise ValueError('parameter {!r}: expected array with shape {!r}, got {!r}'
#     505                          .format(param, shape, array.shape))
#     506
#
# ValueError: parameter 'value': expected array with shape (1,), got (3,)
