# %%
from prototype2_SizeSlabModel import ASTroCATclone, new_plot

# %%
import pickle
filehandler = open('forcing_47_minus20.obj', 'rb') 
forx = pickle.load(filehandler)

# %%
import numpy as np
import xsimlab as xs
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
ASTroCATclone
# Out:
# <xsimlab.Model (6 processes, 26 inputs)>
# physx
#     lon                 [in]
#     lat                 [in]
#     rbb                 [in]
# P
#     OptI                [in]
#     NP                  [in] number of P - and Z
#     PMaxEsd             [in] P size range maximum ESD
#     kc                  [in]
#     PMinEsd             [in] P size range minimum ESD
#     component_label     [in]
#     initVal             [in] initial total Phytoplankton concentration
#     kw                  [in]
#     m                   [in] Phytoplankton mortality
# Z
#     epsilon             [in] assimilated grazed biomass
#     deltaxprey          [in] log10 prey size tolerance
#     zeta                [in] Z quadratic mortality
#     f_eg                [in] egested grazed biomass
#     KsZ                 [in] grazing half saturation constant
#     initVal             [in] initial total Zooplankton concentration
#     component_label     [in]
# D
#     remin_rate          [in] Detritus remineralization rate
#     component_label     [in]
#     initVal             [in] initial Detritus concentration
# N
#     component_label     [in]
#     supplyrate          [in] Nutrient supply rate
#     initVal             [in] initial Nutrient concentration
# env
#     kappa               [in]

# %%
# RUN 57

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .01,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 8,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_57.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 58

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .01,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 8,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.15,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_58.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 59

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .01,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':12,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 8,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.15,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_59.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 60

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .01,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':12,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 8,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.2,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_60.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 61

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .01,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':15,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 8,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.15,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_61.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 62

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .01,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':12,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 7.5,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.15,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_62.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 63

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .01,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':12,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 7,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.15,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_63.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 64

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .01,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':12,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 6,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.15,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_64.pdf', bbox_inches='tight')
