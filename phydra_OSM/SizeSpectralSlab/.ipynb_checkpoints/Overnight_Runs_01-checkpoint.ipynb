# %%
from prototype1_SizeSlabModel import ASTroCATclone, new_plot

# %%
import pickle
filehandler = open('forcing_47_minus20.obj', 'rb') 
forx = pickle.load(filehandler)

# %%
import numpy as np
import xsimlab as xs
from scipy.integrate import odeint
import matplotlib.pyplot as plt

# %%
ASTroCATclone
# Out:
# <xsimlab.Model (6 processes, 26 inputs)>
# physx
#     lat                 [in]
#     lon                 [in]
#     rbb                 [in]
# P
#     OptI                [in]
#     PMinEsd             [in] P size range minimum ESD
#     component_label     [in]
#     m                   [in] Phytoplankton mortality
#     kw                  [in]
#     initVal             [in] initial total Phytoplankton concentration
#     PMaxEsd             [in] P size range maximum ESD
#     NP                  [in] number of P - and Z
#     kc                  [in]
# Z
#     epsilon             [in] assimilated grazed biomass
#     f_eg                [in] egested grazed biomass
#     initVal             [in] initial total Zooplankton concentration
#     KsZ                 [in] grazing half saturation constant
#     deltaxprey          [in] log10 prey size tolerance
#     zeta                [in] Z quadratic mortality
#     component_label     [in]
# N
#     initVal             [in] initial Nutrient concentration
#     supplyrate          [in] Nutrient supply rate
#     component_label     [in]
# D
#     component_label     [in]
#     remin_rate          [in] Detritus remineralization rate
#     initVal             [in] initial Detritus concentration
# env
#     kappa               [in]

# %%
# RUN 01

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':30,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_01.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_01.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 02

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':30,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 30,       # grazing half saturation constant  # 3 '!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!'!
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_02.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_02.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 03

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':30,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 6,       # grazing half saturation constant  # 3  '!'!''!'!'!'!'!'!'!''!'!'!'!''!'!'!'!''!'!'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_03.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_03.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 04

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':30,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        
        'env__kappa':0.5  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_04.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_04.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 05

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':30,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 1,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_05.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
data_coordfix = model_out.set_index(component = 'env__component', P__sizes='P__size', Z__sizes='Z__size')

P_out = data_coordfix.sel(component=['P'+str(i) for i in range(10)]) #40
Z_out = data_coordfix.sel(component=['Z'+str(i) for i in range(10)]) #40
N_out = data_coordfix.sel(component='N')
D_out = data_coordfix.sel(component='D')

# %%
P_out.P__sizes
# Out:
# <xarray.DataArray 'P__sizes' (P__sizes: 10)>
# array([ 0.5     ,  0.83405 ,  1.39128 ,  2.320794,  3.871318,  6.457748,
#        10.772173, 17.969068, 29.974213, 50.      ])
# Coordinates:
#   * P__sizes  (P__sizes) float64 0.5 0.8341 1.391 2.321 ... 17.97 29.97 50.0

# %%
P_out.plot.scatter(x='time',y='env__stateout')

# %%
Z_out.plot.scatter(x='time',y='env__stateout')

# %%
N_out.plot.scatter(x='time',y='env__stateout')

# %%
D_out.plot.scatter(x='time',y='env__stateout')

# %%
# RUN 06

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':20,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 1,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_06.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 07

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*35,365*35*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':30,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 1,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_07.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 08

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':30,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 1.5,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_08.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 09

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':20,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 1.2,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_09.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 10

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 1.2,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_10.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 11

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 1.3,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_11.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 12

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 1.5,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_12.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 13

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 2,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_13.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 14

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 2.5,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_14.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 15

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 2.9,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_15.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 16

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':15,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 2.9,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx)

plt.savefig('ONR1_output_16.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 17

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 2.9,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_17.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 18

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 10,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .2,      # mortality rate quadratic    '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 2.9,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 10)

plt.savefig('ONR1_output_18.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.83405027  1.3912797   2.32079442  3.87131841  6.45774833
#  10.77217345 17.96906832 29.97421252 50.        ]

# %%
# RUN 19

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_19.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 20

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .05,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_20.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 21

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .05,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_21.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 22

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .05,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_22.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 23

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .05,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.04,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_23.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 24

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .01,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.04,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_24pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 25

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .01,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.01,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_25pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 26

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .01,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 2.5,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.01,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_26.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 27

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .01,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 4,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.01,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_27.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 28

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .1,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':20,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .01,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 2.5,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.01,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_28.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]

# %%
# RUN 28

model_in = xs.create_setup(
        model=ASTroCATclone,
    clocks={
         'time': np.linspace(1,365*15,365*15*60)  # 10*365,10*365*9)
     },
    input_vars={
        'N__initVal':1,    # inital Nutrient amount
        'N__supplyrate':5, # nutrient supply rate
        
        'P__initVal': 1,   # inital total biomass of Phytoplankton
        'P__PMinEsd': .5,   # minimal Phytoplankton Size Spectral range
        'P__PMaxEsd': 50,  # minimal Phytoplankton Size Spectral range
        'P__NP': 20,       # number of Phytoplankton Types (=num of Zooplankton Types)
        'P__m': .05,        # mortality rate of Phytoplankton
        'P__kw': 0.4,
        'P__kc': 0.3,
        'P__OptI':10,
        
        'Z__initVal': 1,   # inital total biomass of Zooplankton
        'Z__zeta': .1,      # mortality rate quadratic
        'Z__deltaxprey': .25,  # log10 prey size tolerance
        'Z__KsZ': 3,       # grazing half saturation constant  # 3 '"'"'"'"'"'"':!:!:!:!:!::!:!:!::!:!:!::!!'"'"'"'"'"'"'
        'Z__f_eg': .33,    # egested food
        'Z__epsilon': .33,  # assimilated food
        
        'D__initVal': 0.1,  # initial Detritus Biomass
        'D__remin_rate': 0.1,  # Detritus remineralization rate
        
        'env__kappa':0.1  # diffusive mixing constant
    },
    output_vars={
        'env__component': None,
        'P__size': None,
        'Z__size': None,
        'env__stateout': 'time'
    }
)



model_out = model_in.xsimlab.run(model=ASTroCATclone)


#model_out.to_netcdf('output_05.nc')


new_plot(model_out,forx, 20)

plt.savefig('ONR1_output_28.pdf', bbox_inches='tight')
# Out:
# [ 0.5         0.63713749  0.81188837  1.03456904  1.31832545  1.67990914
#   2.1406662   2.72779739  3.47596398  4.42933395  5.64418946  7.19224944
#   9.16490355 11.67860735 14.88175721 18.96345095 24.16465119 30.79241055
#  39.23799852 50.        ]
