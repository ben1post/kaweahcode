# %%
import matplotlib.pyplot as plt
import xarray as xr
import numpy as np

# %%
plt.rcParams['figure.figsize'] = [15, 10]

# %%
# 1.plot: contour plot y=size, x=time, col=concentration

# %%
data = xr.open_dataset('NEW_ASTroCAT_10yearoutput_x70res.nc')

# %%
data
# Out:
# <xarray.Dataset>
# Dimensions:             (component: 81, time: 255500)
# Coordinates:
#   * time                (time) float64 1.0 1.014 1.029 ... 3.65e+03 3.65e+03
# Dimensions without coordinates: component
# Data variables:
#     Z__zeta             int64 ...
#     N__supplyrate       int64 ...
#     Z__component_label  object ...
#     Z__f_eg             float64 ...
#     P__PMinEsd          int64 ...
#     Z__deltaxprey       float64 ...
#     P__PMaxEsd          int64 ...
#     Z__KsZ              int64 ...
#     Z__epsilon          float64 ...
#     P__NP               int64 ...
#     N__component_label  object ...
#     P__component_label  object ...
#     P__m                float64 ...
#     N__initVal          int64 ...
#     P__initVal          int64 ...
#     Z__initVal          int64 ...
#     env__stateout       (time, component) float64 ...
#     env__component      (component) object ...

# %%
model_out = data.set_index(component = 'env__component')

# %%
#calculate sizes:
#numbers = np.array([i for i in range(40)])
#sizes = (np.log(20) - np.log(1))* numbers / (40-1) + np.log(1)

# %%
#sizes

# %%
a = plt.pcolormesh(P_out[:,::500].time,P_out[:,::500].component,P_out[:,::500].values)
a.set_yticks()

a
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-140-2ca9c84aa725> in <module>
#       1 a = plt.pcolormesh(P_out[:,::500].time,P_out[:,::500].component,P_out[:,::500].values)
# ----> 2 a.set_yticks()
#       3
#       4 a
#
# AttributeError: 'QuadMesh' object has no attribute 'set_yticks'

# %%
plt.rcParams['figure.figsize'] = [20, 7]

# %%
P_out = model_out.env__stateout.sel(component=['P'+str(i) for i in range(40)]).T
Z_out = model_out.env__stateout.sel(component=['Z'+str(i) for i in range(40)]).T
N_out = model_out.env__stateout.sel(component='N').T
#plt.show()
P_out
# Out:
# <xarray.DataArray 'env__stateout' (component: 40, time: 255500)>
# [10220000 values with dtype=float64]
# Coordinates:
#   * time       (time) float64 1.0 1.014 1.029 ... 3.65e+03 3.65e+03 3.65e+03
#   * component  (component) object 'P0' 'P1' 'P2' 'P3' ... 'P37' 'P38' 'P39'

# %%
plt.pcolor(P_out[:,::500].time, P_out[:,::500].component, P_out[:,::500].values)
#plt.set_xticks(np.arange(0,24,2))
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-a468d7082c46> in <module>
# ----> 1 plt.pcolor(P_out[:,::500].time, P_out[:,::500].component, P_out[:,::500].values)
#       2 #plt.set_xticks(np.arange(0,24,2))
#       3 plt.colorbar()
#       4 plt.show()
#
# ~/opt/anaconda3/envs/xsimlab/lib/python3.8/site-packages/matplotlib/pyplot.py in pcolor(alpha, norm, cmap, vmin, vmax, data, *args, **kwargs)
#    2706         *args, alpha=None, norm=None, cmap=None, vmin=None,
#    2707         vmax=None, data=None, **kwargs):
# -> 2708     __ret = gca().pcolor(
#    2709         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2710         vmax=vmax, **({"data": data} if data is not None else {}),
#
# ~/opt/anaconda3/envs/xsimlab/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
plt.pcolor(P_out)
plt.colorbar()
plt.show()

# %%
plt.pcolor(Z_out)
plt.colorbar()
plt.show()

# %%
plt.plot(N_out)
plt.show()

# %% [markdown]
# # FINAL PLOT

# %%
plt.rcParams['figure.figsize'] = [10, 20]

f1, (ax1, ax2, ax3) = plt.subplots(3, 1, sharey='col')#, sharey='row')

plt.setp((ax1, ax2, ax3), xticks=[1,365,365*2,365*3,365*4,365*5,365*6,365*7,365*8,365*9,365*10])
from matplotlib.ticker import MaxNLocator
for axe in (ax1, ax2, ax3):
    for i in range(numcols):
        
        axe.grid(True, alpha=0.5)
        axe.get_yaxis().set_major_locator(MaxNLocator(nbins=4))
        axe.tick_params(top=False, right=True, direction="in")
        
    #par1.tick_params(direction="in", axis='y', colors='b', **tkw)


increase=1
yvals=np.arange(0,20,increase)

ax1.pcolormesh(P_out[:,::500].time,P_out[:,::500].component,P_out[:,::500].values)
ax1.set_yticks(yvals)
ax1.set_xticks(P_out.time[::36500])

ax2.pcolormesh(P_out[:,::500].time,P_out[:,::500].component,P_out[:,::500].values)
ax2.set_xticks(P_out.time[::36500])

ax3.pcolor(Z_out[:,::500].time,Z_out[:,::500].component,Z_out[:,::500].values)
ax3.set_xticks(P_out.time[::36500])

# Defining custom 'xlim' and 'ylim' values.
#xlim = (0, 365)

# Setting the values for all axes.
#plt.setp((ax1, ax2, ax3), xlim=xlim)

f1.align_ylabels()

#plt.tight_layout()

plt.subplots_adjust(hspace=0.2)

#plt.savefig('Figure4.pdf', bbox_inches='tight')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-145-072a72fffc06> in <module>
#      25 ax2.set_xticks(P_out.time[::36500])
#      26
# ---> 27 ax3.pcolor(Z_out[:,::500].time,Z_out[:,::500].component,Z_out[:,::500].values)
#      28 ax3.set_xticks(P_out.time[::36500])
#      29
#
# ~/opt/anaconda3/envs/xsimlab/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1541     def inner(ax, *args, data=None, **kwargs):
#    1542         if data is None:
# -> 1543             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1544
#    1545         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~/opt/anaconda3/envs/xsimlab/lib/python3.8/site-packages/matplotlib/axes/_axes.py in pcolor(self, alpha, norm, cmap, vmin, vmax, *args, **kwargs)
#    5839
# ...

# %%
P_out.time[::5000]
# Out:
# <xarray.DataArray 'time' (time: 52)>
# array([1.000000e+00, 7.240928e+01, 1.438186e+02, 2.152278e+02, 2.866371e+02,
#        3.580464e+02, 4.294557e+02, 5.008650e+02, 5.722743e+02, 6.436835e+02,
#        7.150928e+02, 7.865021e+02, 8.579114e+02, 9.293207e+02, 1.000730e+03,
#        1.072139e+03, 1.143549e+03, 1.214958e+03, 1.286367e+03, 1.357776e+03,
#        1.429186e+03, 1.500595e+03, 1.572004e+03, 1.643413e+03, 1.714823e+03,
#        1.786232e+03, 1.857641e+03, 1.929051e+03, 2.000460e+03, 2.071869e+03,
#        2.143278e+03, 2.214688e+03, 2.286097e+03, 2.357506e+03, 2.428916e+03,
#        2.500325e+03, 2.571734e+03, 2.643143e+03, 2.714553e+03, 2.785962e+03,
#        2.857371e+03, 2.928781e+03, 3.000190e+03, 3.071599e+03, 3.143008e+03,
#        3.214418e+03, 3.285827e+03, 3.357236e+03, 3.428646e+03, 3.500055e+03,
#        3.571464e+03, 3.642873e+03])
# Coordinates:
#   * time     (time) float64 1.0 72.41 143.8 ... 3.5e+03 3.571e+03 3.643e+03
# Attributes:
# ...
